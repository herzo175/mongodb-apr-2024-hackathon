# %%
import openai
import os

# %%
client = openai.Client(api_key=os.environ["openai_api_key"])

# %%
# Read srt file and return a string
def read_srt(file_path):
    with open(file_path, 'r') as file:
        return file.read()

messi = read_srt("messi.srt")
print(messi)
# Out:
# 1
# 00:00:00,080 --> 00:00:03,360
# it's barcelona paris saint-germain
#
# 2
# 00:00:03,360 --> 00:00:05,600
# the last 16 of the little competition
#
# 3
# 00:00:05,600 --> 00:00:08,240
# called the champions league
#
# 4
# 00:00:08,240 --> 00:00:09,960
# absolutely
#
# 5
# 00:00:09,960 --> 00:00:12,800
# incredible atmosphere in the stadium
#
# 6
# 00:00:12,800 --> 00:00:17,040
# rafinha will play it into the
#
# 7
# 00:00:20,240 --> 00:00:25,500
# [Applause]
#
# 8
# 00:00:27,279 --> 00:00:30,279
# up
#
# 9
# 00:00:31,840 --> 00:00:34,719
# unable to clear it there was a flick
#
# 10
# 00:00:34,719 --> 00:00:36,260
# back by luis suarez
#
# 11
# 00:00:36,260 --> 00:00:42,160
# [Applause]
#
# 12
# 00:00:42,160 --> 00:00:45,600
# messi strikes it oh
#
# 13
# 00:00:45,600 --> 00:00:47,280
# not too far
#
# 14
# 00:00:47,280 --> 00:00:49,840
# over the crossbar there anymore just
#
# 15
# 00:00:49,840 --> 00:00:54,160
# upside the bounty box on the far side
#
# 16
# 00:00:54,640 --> 00:00:57,199
# and that is what you need to do as well
#
# 17
# 00:00:57,199 --> 00:01:00,719
# the elaborate one twos into the box
#
# 18
# 00:01:00,719 --> 00:01:02,480
# flings it inside to a niece who lets him
#
# 19
# 00:01:02,480 --> 00:01:04,159
# run for sweating sweating looking to
#
# 20
# 00:01:04,159 --> 00:01:06,479
# play it over towards iniesta iniesta
#
# 21
# 00:01:06,479 --> 00:01:09,439
# wins the ball back eel
#
# 22
# 00:01:09,760 --> 00:01:11,060
# oh
#
# 23
# 00:01:11,060 --> 00:01:14,889
# [Applause]
#
# 24
# 00:01:15,040 --> 00:01:18,040
# time
#
# 25
# 00:01:26,990 --> 00:01:37,200
# [Applause]
#
# 26
# 00:01:37,200 --> 00:01:38,840
# waiting for the
#
# 27
# 00:01:38,840 --> 00:01:41,119
# whistle there it is
#
# 28
# 00:01:41,119 --> 00:01:45,280
# messi steps up hits you into the net
#
# 29
# 00:01:45,280 --> 00:01:48,720
# and it's a cracker of a penalty
#
# 30
# 00:01:48,720 --> 00:01:51,520
# ambassador
#
# 31
# 00:01:52,079 --> 00:01:54,560
# now psg go forward the ball
#
# 32
# 00:01:54,560 --> 00:01:57,840
# is off the post
#
# 33
# 00:01:59,680 --> 00:02:00,799
# and then
#
# 34
# 00:02:00,799 --> 00:02:03,920
# go defensive as the long ball forward
#
# 35
# 00:02:03,920 --> 00:02:07,520
# falls to the spot oh it's a goal
#
# 36
# 00:02:07,520 --> 00:02:11,440
# it's a goal for cavani
#
# 37
# 00:02:15,599 --> 00:02:17,599
# has made the run he's not upside down he
#
# 38
# 00:02:17,599 --> 00:02:20,480
# commanding oh what a save by stegen
#
# 39
# 00:02:20,480 --> 00:02:24,400
# tremendous saving messi messi inside
#
# 40
# 00:02:24,400 --> 00:02:26,800
# there he shoots um
#
# 41
# 00:02:26,800 --> 00:02:28,480
# just wide
#
# 42
# 00:02:28,480 --> 00:02:30,720
# let's see what neymar can do here neymar
#
# 43
# 00:02:30,720 --> 00:02:33,360
# hits it oh what a goal what a goal by
#
# 44
# 00:02:33,360 --> 00:02:36,190
# neymar what a beautiful free kick
#
# 45
# 00:02:36,190 --> 00:02:40,050
# [Applause]
#
# 46
# 00:02:40,050 --> 00:02:43,189
# [Music]
#
# 47
# 00:02:44,480 --> 00:02:46,319
# the players urging the ball forward into
#
# 48
# 00:02:46,319 --> 00:02:48,720
# the box louis swelling is brought down
#
# 49
# 00:02:48,720 --> 00:02:51,599
# it's a penalty it's a penalty it's a
#
# 50
# 00:02:51,599 --> 00:02:57,040
# penalty oh my dear me dear me dear me
#
# 51
# 00:02:57,040 --> 00:02:59,280
# neymar steps up
#
# 52
# 00:02:59,280 --> 00:03:01,200
# is it the net
#
# 53
# 00:03:01,200 --> 00:03:04,200
# nemo
#
# 54
# 00:03:04,239 --> 00:03:08,159
# has made him five one
#
# 55
# 00:03:08,159 --> 00:03:12,000
# he's made it 5-1
#
# 56
# 00:03:13,840 --> 00:03:15,519
# they're going for that ball now um teddy
#
# 57
# 00:03:15,519 --> 00:03:17,680
# will play him into the box pk on the
#
# 58
# 00:03:17,680 --> 00:03:19,440
# other
#
# 59
# 00:03:19,440 --> 00:03:22,239
# ball collected by 12
#
# 60
# 00:03:22,239 --> 00:03:25,680
# and he gave could this be the time ball
#
# 61
# 00:03:25,680 --> 00:03:27,760
# played into the box and it went towards
#
# 62
# 00:03:27,760 --> 00:03:30,319
# test again ball cleared but it'll be a
#
# 63
# 00:03:30,319 --> 00:03:32,879
# chance to play it in again neymar on the
#
# 64
# 00:03:32,879 --> 00:03:35,280
# ball though gets onto his left foot and
#
# 65
# 00:03:35,280 --> 00:03:37,120
# plays into the box
#
# 66
# 00:03:37,120 --> 00:03:39,440
# he's in the right he see the knight he's
#
# 67
# 00:03:39,440 --> 00:03:42,080
# in the net he's in the net he's in the
#
# 68
# 00:03:42,080 --> 00:03:44,840
# net he's in the net
#
# 69
# 00:03:44,840 --> 00:03:47,040
# barcelona have
#
# 70
# 00:03:47,040 --> 00:03:48,159
# one
#
# 71
# 00:03:48,159 --> 00:03:50,080
# six
#
# 72
# 00:03:50,080 --> 00:03:51,319
# one
#
# 73
# 00:03:51,319 --> 00:03:54,159
# barcelona have won
#
# 74
# 00:03:54,159 --> 00:03:57,120
# and they're in the next round of the
#
# 75
# 00:03:57,120 --> 00:04:00,920
# champions league
#
# 76
# 00:04:03,599 --> 00:04:05,040
# 6-1 this
#
# 77
# 00:04:05,040 --> 00:04:06,640
# is history
#
# 78
# 00:04:06,640 --> 00:04:08,319
# this has not
#
# 79
# 00:04:08,319 --> 00:04:10,480
# been done before
#
# 80
# 00:04:10,480 --> 00:04:12,799
# and i don't know if we'll ever see it
#
# 81
# 00:04:12,799 --> 00:04:15,439
# ever again
#
# 82
# 00:04:15,439 --> 00:04:17,680
# but this is the kind of victory that not
#
# 83
# 00:04:17,680 --> 00:04:18,720
# only
#
# 84
# 00:04:18,720 --> 00:04:21,279
# gets you to the next round
#
# 85
# 00:04:21,279 --> 00:04:24,639
# and i tell you what what a beautiful
#
# 86
# 00:04:24,639 --> 00:04:27,440
# ball headed away by machole there's the
#
# 87
# 00:04:27,440 --> 00:04:29,040
# final whistle
#
# 88
# 00:04:29,040 --> 00:04:31,040
# there's the final whistle
#
# 89
# 00:04:31,040 --> 00:04:33,440
# barcelona
#
# 90
# 00:04:33,440 --> 00:04:34,720
# six
#
# 91
# 00:04:34,720 --> 00:04:37,199
# harry sanja man
#
# 92
# 00:04:37,199 --> 00:04:39,120
# one
#
# 93
# 00:04:39,120 --> 00:04:41,440
# bossa
#
# 94
# 00:04:41,440 --> 00:04:43,919
# and in the next round of the champions
#
# 95
# 00:04:43,919 --> 00:04:45,120
# league
#
# 96
# 00:04:45,120 --> 00:04:48,840
# i love this job
#
# 97
# 00:04:49,080 --> 00:04:53,040
# [Applause]

# %%
completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a helpful video transcriber. You will be given the subtitles of a video and you need to convert it into text. Don't make things up. Just write what you hear. The user will provide you with the subtitles. Generate a summary of what is being said in the subtitles. The summary should not acknowledge the subtitles. Make sure to write in your own words and understand the context and meaning of the subtitles. Give out minimum 6 sentences."},
    {"role": "user", "content": messi}
  ]
)

# %%
print(completion.choices[0].message.content)
# Out:
# Barcelona and Paris Saint-Germain are facing each other in the last 16 of the Champions League. The match has an incredible atmosphere with fans cheering on the players. Both teams are giving their all on the field, with Messi, Neymar, and Cavani showcasing their skills. The game ends with Barcelona winning 6-1, securing their spot in the next round. The victory is historic and may not be seen again, showing the talent and determination of the players. It was a thrilling match filled with goals, penalties, and fantastic plays.
