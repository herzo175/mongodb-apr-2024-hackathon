# %%
from nomic import embed, login
import glob
import os

# %%
# Get all images from the "output_images" directory
images = glob.glob("output_images/image_0001.png")
print(images)
# Out:
# ['output_images/image_0001.png']

# %%
login(token=os.environ["nomic_api_key"])

# %%
embed.text(texts=["Hello, this is a test message"])
# Out:
# {'embeddings': [[-0.014884949,
#    0.02848816,
#    0.01789856,
#    -0.011054993,
#    0.05480957,
#    0.027786255,
#    -0.016220093,
#    -0.031463623,
#    0.0031719208,
#    -0.045562744,
#    -0.050872803,
#    0.021774292,
#    -0.019866943,
#    0.01197052,
#    -0.011192322,
#    -0.07861328,
#    0.084228516,
#    -0.021728516,
#    -0.010276794,
#    0.019378662,
#    0.0065994263,
#    -0.017105103,
#    -0.022216797,
#    -0.045318604,
#    0.032928467,
#    0.019683838,
#    -0.029129028,
#    -0.012817383,
#    -0.02204895,
#    -0.007221222,
#    0.030975342,
#    0.0062828064,
#    0.031951904,
#    -0.068847656,
#    0.0006804466,
#    -0.05718994,
#    -0.00015485287,
#    0.018585205,
#    0.05670166,
#    -0.001124382,
#    0.045166016,
#    0.04147339,
#    -0.043426514,
#    -0.033966064,
#    0.03753662,
#    0.027999878,
#    0.020843506,
#    0.020721436,
#    0.038726807,
#    -0.062561035,
#    -0.0011844635,
#    0.032714844,
#    0.012748718,
# ...

# %%
embed.images(images=images)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <HTML><HEAD><META HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=iso-8859-1">
# <TITLE>ERROR: The request could not be satisfied</TITLE>
# </HEAD><BODY>
# <H1>504 ERROR</H1>
# <H2>The request could not be satisfied.</H2>
# <HR noshade size="1px">
# CloudFront attempted to establish a connection with the origin, but either the attempt failed or the origin closed the connection.
# We can't connect to the server for this app or website at this time. There might be too much traffic or a configuration error. Try again later, or contact the app or website owner.
# <BR clear="all">
# If you provide content to customers through CloudFront, you can find steps to troubleshoot and help prevent this error by reviewing the CloudFront documentation.
# <BR clear="all">
# <HR noshade size="1px">
# <PRE>
# Generated by cloudfront (CloudFront)
# ...
